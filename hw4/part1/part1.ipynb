# %%
# !pip -q install -U huggingface_hub

from google.colab import userdata
from huggingface_hub import InferenceClient

hf_token = userdata.get("HF_TOKEN")
assert hf_token, "HF_TOKEN secret not found. Add it in the Secrets panel."

client = InferenceClient(provider="nebius", api_key=hf_token)

image = client.text_to_image(
    "Fish reading a book",
    model="black-forest-labs/FLUX.1-schnell",
)
image
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.3/563.3 kB 9.5 MB/s eta 0:00:00
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=512x512>
